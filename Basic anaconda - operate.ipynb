# %% [markdown]
# ## 創建環境
#
# ### conda create --name new_env python=3.6

# %% [markdown]
# ## 切換環境
#
# ### (source) activate new_env

# %% [markdown]
# ## 為新環境 在 jupyter 也能使用
#
# ### pip install ipykernel
# ### python -m ipykernel install --name new_env --display-name "new_env"

# %% [markdown]
# ## 開啟jupyter lab
#
# ### jupyter lab

# %% [markdown]
# ## 離開環境
#
# ### (source deactivate)
