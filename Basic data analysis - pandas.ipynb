# %% [markdown]
# # Python資料分析絕對繞不過的四個包是
# ## numpy、scipy、pandas還有matplotlib

# %% [markdown]
# ## pandas處理結構化資料

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
frame2 = DataFrame(np.arange(1,10).reshape(3, 3), columns = list((0,1,2)), index = list((0,1,2)))
frame2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
def max_subtract_min(data):
    return max(data)-min(data)

# %%
frame2.apply(max_subtract_min, axis = 0)
# Out:
# 0    6
# 1    6
# 2    6
# dtype: int64
